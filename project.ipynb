# %%
# !git clone https://github.com/AngelLagr/Object-Detection-Project.git
# Out:
# Cloning into 'Object-Detection-Project'...
# remote: Enumerating objects: 6193, done.
# remote: Total 6193 (delta 0), reused 0 (delta 0), pack-reused 6193 (from 2)
# Receiving objects: 100% (6193/6193), 562.67 MiB | 39.23 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# Updating files: 100% (6218/6218), done.

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 932.9/932.9 kB 27.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 64.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 97.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

# Vérifier si tout est bien installé
YOLO("yolo11n.pt").info()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 237MB/s]
# YOLO11n summary: 181 layers, 2,624,080 parameters, 0 gradients, 6.6 GFLOPs
# (181, 2624080, 0, 6.614336)

# %%
model = YOLO("yolo11n.pt")  # Charger un modèle pré-entraîné
model.train(data="/content/Object-Detection-Project/dataset/data.yaml", epochs=50, imgsz=640, batch=16)
# Out:
# Ultralytics 8.3.88 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
results = model("/content/Object-Detection-Project/dataset/train/images/00064_jpg.rf.d8a1d745835f9f0156e7773425dcc7f4.jpg")
results = results[0]
results.show()  # Afficher les prédictions
# Out:
# image 1/1 /content/dataset/train/images/00064_jpg.rf.d8a1d745835f9f0156e7773425dcc7f4.jpg: 640x640 8 Pepperonis, 1 Pizza, 1 Tomatoes, 12.7ms
# Speed: 4.4ms preprocess, 12.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=1080x1080>
